# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# STEP 1: CREATE SAMPLE DATASET (with issues)
# =========================
data = {
    'name': ['A', 'B', 'C', 'D', 'E', 'E'],  # duplicate row
    'age': [25, 30, np.nan, 45, 200, 30],      # missing + outlier (200)
    'city': ['Bangalore', 'bngalore', 'Delhi', None, 'Mumbai', 'Mumbai'],  # typo + null
    'salary': [50000, 60000, 55000, None, 1000000, 60000],  # missing + outlier
    'gender': ['Male', 'Female', 'Female', 'Male', None, 'Female']
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   name    age       city     salary  gender
# 0    A   25.0  Bangalore    50000.0    Male
# 1    B   30.0   bngalore    60000.0  Female
# 2    C    NaN      Delhi    55000.0  Female
# 3    D   45.0       None        NaN    Male
# 4    E  200.0     Mumbai  1000000.0    None
# 5    E   30.0     Mumbai    60000.0  Female

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     5 non-null      float64
#  2   city    5 non-null      object
#  3   salary  5 non-null      float64
#  4   gender  5 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 372.0+ bytes

# %%
df.isnull().sum()
# Out:
# name      0
# age       1
# city      1
# salary    1
# gender    1
# dtype: int64

# %%
print("Summary Stats")
print(df.describe())
# Out:
# Summary Stats
#             age          salary
# count    5.0000        5.000000
# mean    66.0000   245000.000000
# std     75.2828   422078.191808
# min     25.0000    50000.000000
# 25%     30.0000    55000.000000
# 50%     30.0000    60000.000000
# 75%     45.0000    60000.000000
# max    200.0000  1000000.000000

# %% [markdown]
# **DATA CLEANING**

# %%
#Remove duplicates
df = df.drop_duplicates()

#Fix inconsistancies
df['city'] = df['city'].str.lower().str.strip()

#Fix type
df['city'] = df['city'].replace({'bngalore':'bangalore'})

print(df)
# Out:
#   name    age       city     salary  gender
# 0    A   25.0  bangalore    50000.0    Male
# 1    B   30.0  bangalore    60000.0  Female
# 2    C    NaN      delhi    55000.0  Female
# 3    D   45.0       None        NaN    Male
# 4    E  200.0     mumbai  1000000.0    None
# 5    E   30.0     mumbai    60000.0  Female

# %%
#Handling Outliers using IQR for age
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)

IQR = Q3-Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR
print(IQR)
print("Lower Bound", lower_bound)
print("Upper Bound", upper_bound)

df = df[(df['age'] >= lower_bound) & (df['age'] <= upper_bound )]
print(df)
# Out:
# 15.0
# Lower Bound 7.5
# Upper Bound 67.5
#   name   age       city   salary  gender
# 0    A  25.0  bangalore  50000.0    Male
# 1    B  30.0  bangalore  60000.0  Female
# 3    D  45.0       None      NaN    Male
# 5    E  30.0     mumbai  60000.0  Female

# %%
#Automation Really cool
# !pip install ydata-profiling
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport

# Load Titanic dataset
df = sns.load_dataset('titanic')

# Generate Profile Report
profile = ProfileReport(df, title='Titanic Data Report', explorative=True)

# Save to file
profile.to_file("titanic_profile_report.html")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.6 MB/s eta 0:00:00
# ...
# /tmp/ipykernel_4192/3328327240.py:5: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
